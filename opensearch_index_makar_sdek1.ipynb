# %% [markdown]
# # OpenSearch: Индексация корпуса в makar_sdek1
#
# Этот ноутбук создаёт индекс `makar_sdek1` с кастомными русскими анализаторами и полем `knn_vector`, затем индексирует документы из `indexes/corpus.json` с векторами размерности 256.

# %%
# If needed, install dependencies (uncomment to run)
# pip install -q opensearch-py requests fastembed sentence-transformers scikit-learn numpy tqdm

# %%
import os
import json
from typing import List, Dict, Any, Iterable, Optional
from dotenv import load_dotenv

import numpy as np
from tqdm import tqdm
from sklearn.decomposition import PCA

import requests
from opensearchpy import OpenSearch, RequestsHttpConnection
from requests.auth import HTTPBasicAuth

load_dotenv()

# %%
# Config
BASE_DIR = "/Users/admin/СДЭК"
CORPUS_JSON = os.path.join(BASE_DIR, "corpus.json")
INDEX_NAME = "makar_ozon"

OPENSEARCH_URL = os.getenv("OPENSEARCH_URL")
OPENSEARCH_USER = os.getenv("OPENSEARCH_USER")
OPENSEARCH_PASSWORD = os.getenv("OPENSEARCH_PASSWORD")

if not OPENSEARCH_URL:
    raise ValueError("OPENSEARCH_URL must be set in environment variables")
if not OPENSEARCH_USER:
    raise ValueError("OPENSEARCH_USER must be set in environment variables")
if not OPENSEARCH_PASSWORD:
    raise ValueError("OPENSEARCH_PASSWORD must be set in environment variables")

print("Using OpenSearch:", OPENSEARCH_URL)
print("Index:", INDEX_NAME)
print("Corpus:", CORPUS_JSON)
# Out:
# Using OpenSearch: https://localhost:9200
# Index: makar_ozon
# Corpus: /Users/admin/СДЭК/corpus.json

# %%
print("Auth user:", OPENSEARCH_USER)
print("Auth password:", "***" if OPENSEARCH_PASSWORD else "<empty>")
# Out:
# Auth user: admin
# Auth password: ***

# %%
YANDEX_API_KEY = os.getenv("YANDEX_API_KEY")
YANDEX_FOLDER_ID = os.getenv("YANDEX_FOLDER_ID")

if not YANDEX_API_KEY:
    raise ValueError("YANDEX_API_KEY must be set in environment variables")
if not YANDEX_FOLDER_ID:
    raise ValueError("YANDEX_FOLDER_ID must be set in environment variables")

os.environ["LLM_PROVIDER"] = os.getenv("LLM_PROVIDER", "yandex")
os.environ["YANDEX_API_KEY"] = YANDEX_API_KEY
os.environ["YANDEX_FOLDER_ID"] = YANDEX_FOLDER_ID
os.environ["YANDEX_LLM_MODEL"] = os.getenv("YANDEX_LLM_MODEL", "yandexgpt-lite")
os.environ["YANDEX_COMPLETION_URL"] = os.getenv("YANDEX_COMPLETION_URL", "https://llm.api.cloud.yandex.net/foundationModels/v1/completion")
os.environ["YANDEX_EMBED_MODEL"] = os.getenv("YANDEX_EMBED_MODEL", "text-search-doc")

print("LLM provider:", os.environ["LLM_PROVIDER"])
print("Yandex folder:", os.environ["YANDEX_FOLDER_ID"])
print("Yandex embed model:", os.environ["YANDEX_EMBED_MODEL"])
print("Yandex API key:", "***" if os.environ.get("YANDEX_API_KEY") else "<empty>")
# Out:
# LLM provider: yandex
# Yandex folder: b1gql4st0j9joerfcttt
# Yandex embed model: text-search-doc
# Yandex API key: ***

# %%
# Index body (exactly as requested, adapted to Python dict)
INDEX_BODY: Dict[str, Any] = {
    "settings": {
        "index": {
            "number_of_shards": 1,
            "number_of_replicas": 0,
            "knn": True,
            "knn.algo_param.ef_search": 100,
            "similarity": {
                "custom_similarity": {
                    "type": "BM25",
                    "k1": 1.2,
                    "b": 0.75,
                    "discount_overlaps": "true",
                }
            },
            "analysis": {
                "filter": {
                    "russian_stemmer": {"type": "stemmer", "language": "russian"},
                    "unique_pos": {"type": "unique", "only_on_same_position": False},
                    "my_multiplexer": {
                        "type": "multiplexer",
                        "filters": [
                            "keyword_repeat",
                            "russian_stemmer",
                            "remove_duplicates",
                        ],
                    },
                },
                "analyzer": {
                    "search_text_analyzer": {
                        "type": "custom",
                        "tokenizer": "standard",
                        "filter": ["lowercase", "my_multiplexer", "unique_pos"],
                        "char_filter": ["e_mapping"],
                    },
                    "ru_international_translit_analyzer": {
                        "type": "custom",
                        "tokenizer": "standard",
                        "filter": [
                            "lowercase",
                            "russian_stemmer"
                        ],
                        "char_filter": ["transliteration_filter", "e_mapping"],
                    },
                    "text_analyzer": {
                        "type": "custom",
                        "tokenizer": "standard",
                        "filter": [
                            "lowercase",
                            "russian_stemmer"
                        ],
                        "char_filter": ["e_mapping"],
                    },
                    "exact_analyzer": {
                        "type": "custom",
                        "tokenizer": "standard",
                        "filter": ["lowercase"],
                        "char_filter": ["e_mapping"],
                    },
                    "text_standard": {"type": "standard"},
                    "text_whitespace": {"type": "whitespace"},
                    "text_lowercase": {
                        "type": "custom",
                        "tokenizer": "standard",
                        "filter": ["lowercase"],
                    },
                },
                "char_filter": {
                    "transliteration_filter": {
                        "type": "mapping",
                        "mappings": [
                            "a => а",
                            "b => б",
                            "v => в",
                            "g => г",
                            "d => д",
                            "e => е",
                            "ye => ё",
                            "zh => ж",
                            "z => з",
                            "i => и",
                            "j => й",
                            "k => к",
                            "l => л",
                            "m => м",
                            "n => н",
                            "o => о",
                            "p => п",
                        ],
                    },
                    "e_mapping": {"type": "mapping", "mappings": ["e => ё"]},
                },
            },
        }
    },
    "mappings": {
        "properties": {
            "text": {
                "type": "text",
                "analyzer": "text_analyzer",
                "similarity": "BM25",
            },
            "source": {"type": "keyword"},
            "chunk_id": {"type": "keyword"},
            "text_vector": {
                "type": "knn_vector",
                "dimension": 256,
                "space_type": "cosinesimil",
                "method": {
                    "name": "hnsw",
                    "engine": "faiss",
                    "parameters": {"ef_construction": 512, "m": 64},
                },
            },
        }
    },
}
print("Index body prepared")
# Out:
# Index body prepared

# %%
def create_client(url: str, user: Optional[str], password: Optional[str]) -> OpenSearch:
    auth = HTTPBasicAuth(user, password) if user and password else None
    client = OpenSearch(
        hosts=[url],
        http_compress=True,
        http_auth=auth,
        use_ssl=url.startswith("https://"),
        verify_certs=False,
        connection_class=RequestsHttpConnection,
        timeout=60,
        max_retries=3,
        retry_on_timeout=True,
    )
    return client

client = create_client(OPENSEARCH_URL, OPENSEARCH_USER, OPENSEARCH_PASSWORD)
print("Client ready")
# Out:
# Client ready

# %%
# Delete if exists and create index
if client.indices.exists(index=INDEX_NAME):
    print(f"Index {INDEX_NAME} exists. Deleting...")
    client.indices.delete(index=INDEX_NAME)

print(f"Creating index {INDEX_NAME}...")
client.indices.create(index=INDEX_NAME, body=INDEX_BODY)
print("Index created")
# Out:
# Creating index makar_ozon...
# Index created
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
# Load corpus
if not os.path.exists(CORPUS_JSON):
    raise FileNotFoundError(f"Corpus not found: {CORPUS_JSON}")

with open(CORPUS_JSON, "r", encoding="utf-8") as f:
    corpus = json.load(f)

print(f"Loaded {len(corpus)} records")

# normalize
docs: List[Dict[str, Any]] = []
for i, item in enumerate(corpus):
    text = (item.get("text") or "").strip()
    md = item.get("metadata") or {}
    if not text:
        continue
    docs.append({
        "_id": md.get("chunk_id") or f"doc-{i}",
        "text": text,
        "source": md.get("source") or "unknown",
        "chunk_id": md.get("chunk_id") or f"doc-{i}",
    })

print(f"Prepared {len(docs)} docs for indexing")
# Out:
# Prepared 167 markdown paragraphs from 14 files in '/Users/admin/Downloads/Telegram Desktop/Документация 2'

# %%
# Embedding pipeline via Yandex Foundation Models (default)
TARGET_DIM = 256
EMBED_PROVIDER = os.getenv("EMBED_PROVIDER", "yandex").lower()

YANDEX_API_KEY = os.getenv("YANDEX_API_KEY")
YANDEX_FOLDER_ID = os.getenv("YANDEX_FOLDER_ID")
YANDEX_EMBED_MODEL = os.getenv("YANDEX_EMBED_MODEL", "text-search-doc")  # or "text-search-query"
YANDEX_EMBEDDINGS_URL = os.getenv(
    "YANDEX_EMBEDDINGS_URL",
    "https://llm.api.cloud.yandex.net/foundationModels/v1/textEmbedding",
)

if EMBED_PROVIDER == "yandex":
    if not (YANDEX_API_KEY and YANDEX_FOLDER_ID):
        raise ValueError("YANDEX_API_KEY and YANDEX_FOLDER_ID are required for Yandex embeddings")

    model_uri = f"emb://{YANDEX_FOLDER_ID}/{YANDEX_EMBED_MODEL}/latest"
    headers = {
        "Authorization": f"Api-Key {YANDEX_API_KEY}",
        "x-folder-id": YANDEX_FOLDER_ID,
        "Content-Type": "application/json",
    }

    def yandex_embed_one(text: str) -> List[float]:
        body = {"modelUri": model_uri, "text": text}
        resp = requests.post(YANDEX_EMBEDDINGS_URL, headers=headers, json=body, timeout=60)
        resp.raise_for_status()
        data = resp.json()
        emb = data.get("embedding") or (data.get("result") or {}).get("embedding")
        if emb is None:
            raise RuntimeError(f"Bad embedding response: {data}")
        return emb

    vectors: List[List[float]] = []
    for d in tqdm(docs, desc="Yandex embeddings"):
        vectors.append(yandex_embed_one(d["text"]))

    X = np.asarray(vectors, dtype=np.float32)
    print("Raw embedding shape:", X.shape)

    raw_dim = X.shape[1] if X.size else TARGET_DIM
    if raw_dim > TARGET_DIM and X.size:
        pca = PCA(n_components=TARGET_DIM, random_state=42)
        X_reduced = pca.fit_transform(X).astype(np.float32)
        print(f"Applied PCA: {raw_dim} -> {TARGET_DIM}")
    elif raw_dim < TARGET_DIM and X.size:
        pad = np.zeros((X.shape[0], TARGET_DIM - raw_dim), dtype=np.float32)
        X_reduced = np.hstack([X, pad]).astype(np.float32)
        print(f"Zero-padded: {raw_dim} -> {TARGET_DIM}")
    else:
        X_reduced = X.astype(np.float32)
        print(f"Using native dim: {raw_dim}")

    for i, d in enumerate(docs):
        d["text_vector"] = X_reduced[i].tolist()

    print("Prepared vectors for docs (Yandex):", len(docs))

else:
    # Local fallback (FastEmbed / SentenceTransformers)
    EMBED_MODEL_NAME = os.getenv("EMBED_MODEL", "intfloat/multilingual-e5-small")
    embed_backend = None
    try:
        from fastembed import TextEmbedding
        _fe = TextEmbedding(model_name=EMBED_MODEL_NAME)
        def embed_batch(texts: List[str]) -> np.ndarray:
            embs = list(_fe.embed(texts))
            return np.asarray(embs, dtype=np.float32)
        embed_backend = f"fastembed:{EMBED_MODEL_NAME}"
    except Exception as e:
        try:
            from sentence_transformers import SentenceTransformer
            _hf = SentenceTransformer(EMBED_MODEL_NAME)
            def embed_batch(texts: List[str]) -> np.ndarray:
                embs = _hf.encode(texts, batch_size=64, show_progress_bar=False, normalize_embeddings=True)
                return np.asarray(embs, dtype=np.float32)
            embed_backend = f"sbert:{EMBED_MODEL_NAME}"
        except Exception as ee:
            raise RuntimeError(f"No embedding backend available: {e} | {ee}")

    print("Embedding backend:", embed_backend)
    batch_size = 256
    all_embeddings: List[np.ndarray] = []
    for i in tqdm(range(0, len(docs), batch_size)):
        batch = [d["text"] for d in docs[i:i+batch_size]]
        if not batch:
            continue
        all_embeddings.append(embed_batch(batch))

    X = np.vstack(all_embeddings) if all_embeddings else np.zeros((0, TARGET_DIM), dtype=np.float32)
    print("Raw embedding shape:", X.shape)

    raw_dim = X.shape[1] if X.size else TARGET_DIM
    if raw_dim > TARGET_DIM and X.size:
        pca = PCA(n_components=TARGET_DIM, random_state=42)
        X_reduced = pca.fit_transform(X).astype(np.float32)
        print(f"Applied PCA: {raw_dim} -> {TARGET_DIM}")
    elif raw_dim < TARGET_DIM and X.size:
        pad = np.zeros((X.shape[0], TARGET_DIM - raw_dim), dtype=np.float32)
        X_reduced = np.hstack([X, pad]).astype(np.float32)
        print(f"Zero-padded: {raw_dim} -> {TARGET_DIM}")
    else:
        X_reduced = X.astype(np.float32)
        print(f"Using native dim: {raw_dim}")

    for i, d in enumerate(docs):
        d["text_vector"] = X_reduced[i].tolist()

    print("Prepared vectors for docs (local):", len(docs))
# Out:
# Yandex embeddings: 100%|██████████| 167/167 [00:36<00:00,  4.60it/s]
# Raw embedding shape: (167, 256)
# Using native dim: 256
# Prepared vectors for docs (Yandex): 167

# %%
len(docs)
# Out:
# 167

# %%
# Bulk indexing
BULK_ENDPOINT = f"/{INDEX_NAME}/_bulk"

lines: List[str] = []
for d in docs:
    # Do not mutate original doc; support re-runs safely
    doc_id = d.get("_id") or f"{d.get('source', 'unknown')}::{d.get('chunk_id', '')}"
    src = {k: v for k, v in d.items() if k != "_id"}  # contains text, source, chunk_id, text_vector
    meta = {"index": {"_index": INDEX_NAME, "_id": doc_id}}
    lines.append(json.dumps(meta, ensure_ascii=False))
    lines.append(json.dumps(src, ensure_ascii=False))

# Chunked send (avoid too large payloads; keep even line count)
chunk_lines = 2000  # lines, not docs
for i in tqdm(range(0, len(lines), chunk_lines)):
    payload = "\n".join(lines[i:i+chunk_lines]) + "\n"
    resp = client.transport.perform_request("POST", BULK_ENDPOINT, body=payload)
    if isinstance(resp, dict) and resp.get("errors"):
        print("Bulk errors in chunk:", sum(1 for it in resp.get("items", []) if (it.get("index") or {}).get("error")))

print(f"Indexed {len(docs)} docs into '{INDEX_NAME}'")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
# Indexed 167 docs into 'makar_ozon'

# %% [markdown]
# # Второй варик индексации

# %%
# Per-doc indexing via requests with explicit _id (idempotent)
from urllib.parse import quote

INDEX_DOC_BASE = f"{OPENSEARCH_URL.rstrip('/')}/{INDEX_NAME}/_doc"
AUTH = HTTPBasicAuth(OPENSEARCH_USER, OPENSEARCH_PASSWORD)

session = requests.Session()
session.auth = AUTH
session.verify = False
session.headers.update({"Content-Type": "application/json"})

ok, err = 0, 0
for idx, d in enumerate(docs):
    doc_id = d.get("_id") or d.get("chunk_id") or f"doc-{idx}"
    url = f"{INDEX_DOC_BASE}/{quote(str(doc_id), safe='')}"
    document = {
        "text": d.get("text", ""),
        "source": d.get("source", "unknown"),
        "chunk_id": d.get("chunk_id", f"doc-{idx}"),
        "text_vector": d.get("text_vector"),
    }
    try:
        resp = session.put(url, json=document, timeout=30)
        try:
            body = resp.json()
        except Exception:
            body = {"raw": resp.text[:1000]}
        print(f"[{idx}] PUT {resp.status_code} id={doc_id} | result={(body.get('result') or body.get('_result') or '')}")
        ok += 1
    except Exception as e:
        print(f"[{idx}] Error indexing id={doc_id}: {e}")
        err += 1

print(f"Done. ok={ok} err={err}")
# Out:
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [0] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::0 | result=updated
# [1] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::1 | result=updated
# [2] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::2 | result=updated
# [3] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::3 | result=updated
# [4] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::4 | result=updated
# [5] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::5 | result=updated
# [6] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::6 | result=updated
# [7] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::7 | result=updated
# [8] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::8 | result=updated
# [9] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::9 | result=updated
# [10] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::10 | result=updated
# [11] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::11 | result=updated
# [12] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::12 | result=updated
# [13] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::13 | result=updated
# [14] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::14 | result=updated
# [15] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::15 | result=updated
# [16] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::16 | result=updated
# [17] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::17 | result=updated
# [18] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::18 | result=updated
# [19] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::19 | result=updated
# [20] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::20 | result=updated
# [21] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::21 | result=updated
# [22] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::22 | result=updated
# [23] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::23 | result=updated
# [24] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::24 | result=updated
# [25] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::25 | result=updated
# [26] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::26 | result=updated
# [27] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::27 | result=updated
# [28] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::28 | result=updated
# [29] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::29 | result=updated
# [30] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::30 | result=updated
# [31] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::31 | result=updated
# [32] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::32 | result=updated
# [33] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::33 | result=updated
# [34] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::34 | result=updated
# [35] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::35 | result=updated
# [36] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::36 | result=updated
# [37] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::37 | result=updated
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [38] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::38 | result=updated
# [39] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::39 | result=updated
# [40] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::40 | result=updated
# [41] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::41 | result=updated
# [42] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::42 | result=updated
# [43] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::43 | result=updated
# [44] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::44 | result=updated
# [45] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::45 | result=updated
# [46] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::46 | result=updated
# [47] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::47 | result=updated
# [48] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::48 | result=updated
# [49] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::49 | result=updated
# [50] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::50 | result=updated
# [51] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::51 | result=updated
# [52] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::52 | result=updated
# [53] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::53 | result=updated
# [54] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::54 | result=updated
# [55] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::55 | result=updated
# [56] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::56 | result=updated
# [57] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::57 | result=updated
# [58] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::58 | result=updated
# [59] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::59 | result=updated
# [60] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::60 | result=updated
# [61] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::61 | result=updated
# [62] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::62 | result=updated
# [63] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::63 | result=updated
# [64] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::64 | result=updated
# [65] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::65 | result=updated
# [66] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::66 | result=updated
# [67] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::67 | result=updated
# [68] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::68 | result=updated
# [69] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::69 | result=updated
# [70] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::70 | result=updated
# [71] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::71 | result=updated
# [72] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::72 | result=updated
# [73] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::73 | result=updated
# [74] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::74 | result=updated
# [75] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::75 | result=updated
# [76] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::76 | result=updated
# [77] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::77 | result=updated
# [78] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::78 | result=updated
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [79] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::79 | result=updated
# [80] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::80 | result=updated
# [81] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::81 | result=updated
# [82] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::82 | result=updated
# [83] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::83 | result=updated
# [84] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::84 | result=updated
# [85] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::85 | result=updated
# [86] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::86 | result=updated
# [87] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::87 | result=updated
# [88] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::88 | result=updated
# [89] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::89 | result=updated
# [90] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::90 | result=updated
# [91] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::91 | result=updated
# [92] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::92 | result=updated
# [93] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::93 | result=updated
# [94] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::94 | result=updated
# [95] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::95 | result=updated
# [96] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::96 | result=updated
# [97] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::97 | result=updated
# [98] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::98 | result=updated
# [99] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::99 | result=updated
# [100] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::100 | result=updated
# [101] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::101 | result=updated
# [102] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::102 | result=updated
# [103] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::103 | result=updated
# [104] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::104 | result=updated
# [105] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::105 | result=updated
# [106] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::106 | result=updated
# [107] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::107 | result=updated
# [108] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::108 | result=updated
# [109] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::109 | result=updated
# [110] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::110 | result=updated
# [111] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::111 | result=updated
# [112] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::112 | result=updated
# ...
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [119] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::119 | result=updated
# [120] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::120 | result=updated
# [121] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::121 | result=updated
# [122] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::122 | result=updated
# [123] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::123 | result=updated
# [124] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::124 | result=updated
# [125] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::125 | result=updated
# [126] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::126 | result=updated
# [127] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::127 | result=updated
# [128] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::128 | result=updated
# [129] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::129 | result=updated
# [130] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::130 | result=updated
# [131] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::131 | result=updated
# [132] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::132 | result=updated
# [133] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::133 | result=updated
# [134] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::134 | result=updated
# [135] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::135 | result=updated
# [136] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::136 | result=updated
# [137] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::137 | result=updated
# [138] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::138 | result=updated
# [139] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::139 | result=updated
# [140] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::140 | result=updated
# [141] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::141 | result=updated
# [142] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::142 | result=updated
# [143] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::143 | result=updated
# [144] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::144 | result=updated
# [145] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::145 | result=updated
# [146] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::146 | result=updated
# [147] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::147 | result=updated
# [148] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::148 | result=updated
# [149] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::149 | result=updated
# [150] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::150 | result=updated
# [151] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::151 | result=updated
# [152] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::152 | result=updated
# [153] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::153 | result=updated
# [154] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::154 | result=updated
# [155] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::155 | result=updated
# [156] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::156 | result=updated
# [157] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::157 | result=updated
# [158] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::158 | result=updated
# [159] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::159 | result=updated
# [160] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::160 | result=updated
# [161] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::161 | result=updated
# [162] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::162 | result=updated
# [163] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::163 | result=updated
# [164] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::164 | result=updated
# [165] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::165 | result=updated
# [166] PUT 200 id=Sbornik_profilaktika_emotsionalnogo_vygoraniya.pdf::166 | result=updated
# Done. ok=167 err=0
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
from urllib.parse import quote

def hybrid_search_rrf(query_text: str, top_k: int = 10, bm25_size: int = 50, knn_k: int = 50, k_rrf: int = 60):
    bm25_size = max(bm25_size, top_k)
    knn_k = max(knn_k, top_k)

    bm25_body = {
        "size": bm25_size,
        "query": {
            "multi_match": {
                "query": query_text,
                "fields": ["text^2", "source"],
                "type": "best_fields",
                "operator": "and",
                "analyzer": "search_text_analyzer",
            }
        },
        "_source": ["text", "source", "chunk_id"],
    }
    res_bm25 = client.search(index=INDEX_NAME, body=bm25_body)
    bm25_hits = res_bm25.get("hits", {}).get("hits", [])

    # 2) Yandex query embedding + kNN
    YANDEX_API_KEY = os.environ.get("YANDEX_API_KEY")
    YANDEX_FOLDER_ID = os.environ.get("YANDEX_FOLDER_ID")
    YANDEX_EMBEDDINGS_URL = os.environ.get(
        "YANDEX_EMBEDDINGS_URL",
        "https://llm.api.cloud.yandex.net/foundationModels/v1/textEmbedding",
    )
    QUERY_EMBED_MODEL = os.getenv("YANDEX_QUERY_EMBED_MODEL", "text-search-query")
    if not (YANDEX_API_KEY and YANDEX_FOLDER_ID):
        raise ValueError("YANDEX_API_KEY and YANDEX_FOLDER_ID are required for Yandex embeddings")

    headers = {
        "Authorization": f"Api-Key {YANDEX_API_KEY}",
        "x-folder-id": YANDEX_FOLDER_ID,
        "Content-Type": "application/json",
    }
    q_model_uri = f"emb://{YANDEX_FOLDER_ID}/{QUERY_EMBED_MODEL}/latest"
    q_body = {"modelUri": q_model_uri, "text": query_text}
    resp_q = requests.post(YANDEX_EMBEDDINGS_URL, headers=headers, json=q_body, timeout=30)
    resp_q.raise_for_status()
    q_data = resp_q.json()
    q_vec = q_data.get("embedding") or (q_data.get("result") or {}).get("embedding")
    if q_vec is None:
        raise RuntimeError(f"Bad query embedding response: {q_data}")

    knn_body = {
        "size": knn_k,
        "query": {
            "knn": {
                "text_vector": {
                    "vector": q_vec,
                    "k": knn_k
                }
            }
        },
        "_source": ["text", "source", "chunk_id"],
    }
    res_knn = client.search(index=INDEX_NAME, body=knn_body)
    knn_hits = res_knn.get("hits", {}).get("hits", [])

    # RRF merge
    def key_for(hit):
        src = hit.get("_source", {})
        return hit.get("_id") or f"{src.get('source')}::{src.get('chunk_id')}"

    bm25_rank = {key_for(h): i + 1 for i, h in enumerate(bm25_hits)}
    knn_rank = {key_for(h): i + 1 for i, h in enumerate(knn_hits)}

    rrf = {}
    cache = {}
    for i, h in enumerate(bm25_hits, 1):
        k = key_for(h)
        rrf[k] = rrf.get(k, 0.0) + 1.0 / (k_rrf + i)
        cache[k] = h
    for i, h in enumerate(knn_hits, 1):
        k = key_for(h)
        rrf[k] = rrf.get(k, 0.0) + 1.0 / (k_rrf + i)
        cache[k] = h

    fused = sorted(rrf.items(), key=lambda x: x[1], reverse=True)[:top_k]
    results = []
    for rank, (k, score) in enumerate(fused, 1):
        h = cache[k]
        src = h.get("_source", {})
        results.append({
            "rank": rank,
            "rrf_score": score,
            "bm25_rank": bm25_rank.get(k),
            "knn_rank": knn_rank.get(k),
            "source": src.get("source"),
            "chunk_id": src.get("chunk_id"),
            "text": (src.get("text") or "")[:240].replace("\n", " ") + ("..." if len(src.get("text") or "") > 240 else ""),
        })
    return results

# Example run
user_query_text = "профессиональное выгорание профилактика"
TOP_K = 8
res = hybrid_search_rrf(user_query_text, top_k=TOP_K)
for r in res:
    print(f"[{r['rank']}] rrf={r['rrf_score']:.4f} | bm25={r['bm25_rank']} | knn={r['knn_rank']} | {r['source']} #{r['chunk_id']}")
    print(r['text'])
    print("-")
# Out:
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [1] rrf=0.0164 | bm25=None | knn=1 | Жалобы и эскалация инцидентов.md #Жалобы и эскалация инцидентов.md::p6
# Коммуникация с конфликтными и эмоциональными клиентами требует особого стиля речи. Оператор избегает фраз, обесценивающих эмоции клиента, и не призывает его «успокоиться», вместо этого признавая, что ситуация действительно может вызывать не...
# -
# [2] rrf=0.0161 | bm25=None | knn=2 | Жалобы и эскалация инцидентов.md #Жалобы и эскалация инцидентов.md::p4
# При оформлении официальной жалобы оператор обязан чётко и нейтрально описать суть претензии. В тексте жалобы фиксируются полные данные клиента, идентификаторы затронутых продуктов, дата и время инцидента, канал взаимодействия и суть жалобы ...
# -
# [3] rrf=0.0159 | bm25=None | knn=3 | Идентификация клиента и безопасность операций.md #Идентификация клиента и безопасность операций.md::p8
# С точки зрения коммуникации оператор всегда открыто объясняет клиенту, зачем проводится проверка и какие риски она предотвращает. Если клиент возмущён количеством вопросов или настаивает на «исключении», оператор мягко, но твёрдо подчёркива...
# -
# [4] rrf=0.0156 | bm25=None | knn=4 | интернет-банк.md #интернет-банк.md::p8
# Технические сбои и ошибки при работе с интернет‑банком неизбежно приводят к обращениям в контакт‑центр. Здесь задача оператора состоит в том, чтобы отделить локальные проблемы на стороне клиента от инцидентов в инфраструктуре банка. В разго...
# -
# [5] rrf=0.0154 | bm25=None | knn=5 | Жалобы и эскалация инцидентов.md #Жалобы и эскалация инцидентов.md::p12
# Отдельным вопросом является возможность компенсации за неудобства или моральный вред, который клиент испытывает из‑за ошибки банка или длительного разбора. Оператор поясняет, что решение о предоставлении компенсации, скидок или иных мер доб...
# -
# [6] rrf=0.0152 | bm25=None | knn=6 | Ипотечные кредиты и залоговая недвижимость.md #Ипотечные кредиты и залоговая недвижимость.md::p5
# Не менее частыми являются вопросы о досрочном погашении и частичном погашении ипотеки. Оператор разъясняет, что в современных программах чаще всего отсутствуют комиссии за досрочное погашение, но установлены минимальные размеры операций, на...
# -
# [7] rrf=0.0149 | bm25=None | knn=7 | Идентификация клиента и безопасность операций.md #Идентификация клиента и безопасность операций.md::p6
# Особое внимание уделяется распознаванию признаков социальной инженерии. Нередки ситуации, когда клиент звонит под воздействием третьих лиц, читающих ему текст «по шпаргалке» или настаивающих на немедленных операциях, якобы для «спасения» ср...
# -
# [8] rrf=0.0147 | bm25=None | knn=8 | Жалобы и эскалация инцидентов.md #Жалобы и эскалация инцидентов.md::p2
# Любая работа с жалобой начинается с внимательного выслушивания клиента. Даже если оператору уже понятна примерная суть проблемы, перебивать клиента на первых минутах разговора недопустимо: человеку важно высказаться и почувствовать, что его...
# -
# /Users/admin/Library/Python/3.8/lib/python/site-packages/urllib3/connectionpool.py:1064: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
